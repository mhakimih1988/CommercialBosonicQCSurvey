# %% [markdown]
# ## Reference: Continuous QAOA
#
# The explanations and initial implementation in this notebook are based on the excellent blog post:
# **[Continuous QAOA — Luca Manelli (2019)](https://lucaman99.github.io/blog/2019/07/06/Continuous-QAOA.html)**.
#
# In that work, the QAOA algorithm is implemented and simulated using local simulators, focusing on continuous-time evolution with a Hamiltonian approach.
#
# ---
#
# ## My Adaptation
#
# I am adapting their approach to run on **Xanadu's backend simulator** — specifically, the **`simulon_gaussian`** backend. This involves small but important changes in how gates and circuits are constructed to be compatible with the photonic Gaussian model supported by Xanadu’s platform.
#
# I will retain much of the core logic but adjust the encoding, cost Hamiltonian, and time-evolution implementation to suit the continuous-variable quantum framework used by `simulon_gaussian`.

# %% [markdown]
# #### Attempt to Run on Xanadu X8 Hardware
#
# As part of this project, I attempted to implement the CV-QAOA algorithm on **Xanadu’s X8 hardware** — the only available photonic quantum chip on their cloud platform.
#
# However, through discussions with Xanadu’s support team, I learned that the **X8 is a passive device** and **cannot implement displacement operations**, which are required for the cost unitary
# $$e^{i p \hat{x} / \hbar}.$$
#
#
# ##### Why It Cannot Be Implemented on X8
#
# The unitary
# $$e^{i p \hat{x} / \hbar}$$
# **cannot be implemented** on the X8 chip because:
#
# - X8 only supports **passive Gaussian operations** (unitaries on annihilation operators: $\hat{a} \mapsto U\hat{a}$).
# - Passive operations **preserve the origin** in phase space (they can rotate or squeeze, but **not displace**).
# - Displacements are **active transformations** — they change the **first moments** in phase space.
# - Active operations like displacement require **external coherent drives** or **electro-optic modulation**, which **X8 does not support**.
#
#
# ##### Could It Be Emulated Indirectly?
#
# A common question is whether clever combinations of passive components (e.g., interferometers, beam splitters, or phase shifters) could fake a displacement.
#
# **The answer is no**:
#
# - A displacement **cannot** be emulated with interferometers, beam splitters, or phase shifters alone.
# - Even with **multiple modes**, there's no way to generate a displacement without **injecting an external coherent state or ancilla** — which X8 does not permit.

# %% [markdown]
# #### Transition to `simulon_gaussian` Backend and the `Pgate` Issue
#
# After realizing that Xanadu’s **X8 hardware** does not support displacement operations due to its passive nature, I decided to move forward with the **`simulon_gaussian`** backend — a **simulator** that supports a broader set of Gaussian operations.
#
# However, a new limitation emerged:
# Although `simulon_gaussian` supports **displacement and squeezing**, it **does not support the `Pgate`**, which is essential for implementing the quadratic phase
# $$\hat{P}(s) = \exp\left( i \frac{s}{2\hbar} \hat{x}^2 \right).$$
#
# ---
#
# #####  Workaround: Emulating `Pgate` Using Conjugation
#
# To overcome this, I used a known decomposition based on **conjugation with rotation gates**. Specifically, we use the identity:
#
# $$
# \hat{P}(s) = \hat{R}(-\pi/2) \, \hat{Z}(s) \, \hat{R}(\pi/2)
# $$
#
# Here’s what this means:
#
# - **`Pgate(s)`** applies a momentum shear and is equivalent to a **quadratic phase in position**.
# - **`Zgate(z)`** performs a **momentum displacement**:
#   $$\hat{Z}(z) = \exp(i z \hat{x})$$
# - **`Rgate(θ)`** rotates the phase space:
#   $$\hat{R}(θ) = \exp(i θ \hat{n})$$
#   and acts on quadratures as:
#   $$
#   \begin{aligned}
#   \hat{a} &\rightarrow \hat{a} \cos θ + \hat{a}^\dagger \sin θ \\
#   \hat{p} &\rightarrow \hat{p} \cos θ - \hat{x} \sin θ
#   \end{aligned}
#   $$
#
# While neither `Rgate` nor `Zgate` alone can replicate a `Pgate`, their **conjugation** can.
#
# ---
#
# #####  Code Implementation
#
# ```python
# Rgate(-np.pi/2) | q[0]
# Zgate(-2 * hbar * p) | q[0]
# Rgate(np.pi/2) | q[0]

# %%
import strawberryfields as sf
from strawberryfields.ops import *
# from strawberryfields.utils import scale
from numpy import pi, sqrt
import math
import random
import numpy as np

from matplotlib import pyplot as plt

# %%
prog = sf.Program(1)
eng = sf.RemoteEngine("simulon_gaussian")


iterations = 10
shots =  10
parabolic_min = 2
possible_parameters = [0.1, 0.3, 0.5, 0.7, 0.9, 1.1]
testing_trials = 100
optimal_value = math.inf
simulation = []

# %%
#Calculating loss

def function_optimize(x, parabolic_min):
    y = (x - parabolic_min)**2
    return y

# %%
def run_circuit(alpha_param, beta_param, parabolic_min):
    prog = sf.Program(1)

    with prog.context as q:
        for i in range(len(alpha_param)):
            Zgate(parabolic_min * 4 * beta_param[i]) | q[0]
            # Approximate Pgate(-4 * beta_param[i]) using R-Z-R sandwich (not equivalent)
            Rgate(-np.pi/2)     | q[0]
            Zgate(-4 * beta_param[i]) | q[0]
            Rgate(np.pi/2)      | q[0]
            Rgate(-1 * alpha_param[i]) | q[0]
        
        MeasureX | q[0]

    job = eng.run(prog, shots=1)
    return job

# %%
#Search for the optimal value
param_length = 5
op = []

alpha_param = []
beta_param = []


for i in range(param_length):
    alpha_param.append(random.choice(possible_parameters))
    beta_param.append(random.choice(possible_parameters))


for i in range(0, iterations):
    result = 0
    grid = []
    for h in range(0, shots):
        hello = run_circuit(alpha_param, beta_param, parabolic_min)
        result = result + hello.samples[0][0]
        grid.append(hello)
    result = result/shots
    calculation = function_optimize(result, parabolic_min)

    yer_a = alpha_param
    yer_b = beta_param

    if (calculation < optimal_value):
        simulation = grid
        optimal_value = calculation
        the_x_measurement = result
        op = [alpha_param[:], beta_param[:]]

    for i in range(param_length):
        alpha_param[i] = random.choice(possible_parameters)
        beta_param[i] = random.choice(possible_parameters)


optimal_parameters = op
# Out:
# 2025-07-08 00:54:58,031 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:02,258 - INFO - The remote job 06e9337e-0be3-41a1-87b7-4dc2cd35a7f2 has been completed.
# 2025-07-08 00:55:02,579 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:06,786 - INFO - The remote job 94f6807d-34cb-4047-a527-2d83dfb519f7 has been completed.
# 2025-07-08 00:55:07,085 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:09,992 - INFO - The remote job 5641ff08-befb-4486-b71e-3878b77ad08d has been completed.
# 2025-07-08 00:55:10,289 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:13,079 - INFO - The remote job aec23dff-2efa-40a2-aee4-e9fa6835954d has been completed.
# 2025-07-08 00:55:13,409 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:17,847 - INFO - The remote job 15aeaf04-7fdd-4f80-82b8-c7104fc444bd has been completed.
# 2025-07-08 00:55:18,127 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:22,370 - INFO - The remote job f99125fb-681d-4964-b828-355c65ff59c5 has been completed.
# 2025-07-08 00:55:22,696 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:25,614 - INFO - The remote job 1757ebd4-53ad-4d16-9cdd-5760d7fb4467 has been completed.
# 2025-07-08 00:55:25,887 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:28,625 - INFO - The remote job d272cf6e-aab5-4ca8-89ef-1eec63512194 has been completed.
# 2025-07-08 00:55:28,928 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:33,288 - INFO - The remote job e225b560-0628-4856-8315-e97d57c11cfd has been completed.
# 2025-07-08 00:55:33,590 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:37,874 - INFO - The remote job 403b9e05-979a-4387-80cb-ca985713b661 has been completed.
# 2025-07-08 00:55:38,183 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:42,449 - INFO - The remote job 5d74429d-9a1c-413c-a8b1-ce6780afcc70 has been completed.
# 2025-07-08 00:55:42,775 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:45,607 - INFO - The remote job 83650930-b0be-4a3f-bdb6-fc042a50a122 has been completed.
# 2025-07-08 00:55:45,900 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:48,612 - INFO - The remote job 6f8f07fe-d76e-44b6-a8dd-157658dfa331 has been completed.
# 2025-07-08 00:55:48,906 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:52,921 - INFO - The remote job 33ed487e-04c9-4258-a47f-1d5a4a8c18c0 has been completed.
# 2025-07-08 00:55:53,255 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:55:57,503 - INFO - The remote job 06c41035-24a0-453c-9e6b-4525337198b1 has been completed.
# 2025-07-08 00:55:57,780 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:02,230 - INFO - The remote job f8322360-777d-4f6a-acb3-588e8bc972e0 has been completed.
# 2025-07-08 00:56:02,578 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:06,853 - INFO - The remote job 072c23f9-5e21-4663-aaa6-4d85381f61a9 has been completed.
# 2025-07-08 00:56:07,157 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:10,088 - INFO - The remote job d8bcc37b-a261-4532-842f-97a15d39b6a1 has been completed.
# 2025-07-08 00:56:10,394 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:13,108 - INFO - The remote job 7f7bc2f9-0017-4611-bdc5-75550b8578cf has been completed.
# 2025-07-08 00:56:13,441 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:17,730 - INFO - The remote job 2eda8291-0533-4904-ac1c-92b439736ee6 has been completed.
# 2025-07-08 00:56:18,052 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:22,246 - INFO - The remote job 3694b8b4-8851-4fae-a06b-c389f8b53ff0 has been completed.
# 2025-07-08 00:56:22,571 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:26,930 - INFO - The remote job de882668-7bb3-48d1-b9ea-52470efdbefb has been completed.
# 2025-07-08 00:56:27,254 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:30,215 - INFO - The remote job a34d01a7-ea34-4bbe-9e7c-c25af2a98364 has been completed.
# 2025-07-08 00:56:30,517 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:33,532 - INFO - The remote job 440da66f-52a5-452b-939a-95f7189adaff has been completed.
# 2025-07-08 00:56:33,810 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:37,096 - INFO - The remote job b3e6e9ab-250c-407e-bd2f-7e3c0ded9715 has been completed.
# 2025-07-08 00:56:37,385 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00:56:40,268 - INFO - The remote job 7435a982-89df-466b-9811-41e298b4cb4b has been completed.
# 2025-07-08 00:56:40,554 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 00
- INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:25,232 - INFO - The remote job 5e85616d-39eb-48fd-969b-69f1fe76408f has been completed.
# 2025-07-08 01:01:25,520 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:30,085 - INFO - The remote job 2f78173e-fc73-4b06-b264-c9cbbab3854f has been completed.
# 2025-07-08 01:01:30,419 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:34,678 - INFO - The remote job c3756d84-e119-4ee4-a4bb-46afe592f279 has been completed.
# 2025-07-08 01:01:34,984 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:39,526 - INFO - The remote job 42ee0845-25e3-4ec4-862f-24e0809851f2 has been completed.
# 2025-07-08 01:01:39,820 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:43,074 - INFO - The remote job 26747e78-a1e3-4e58-8e67-d68dd6f7fd21 has been completed.
# 2025-07-08 01:01:43,371 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:47,721 - INFO - The remote job d11fcf04-f624-431b-9a89-951ce40c5c98 has been completed.
# 2025-07-08 01:01:47,992 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:52,154 - INFO - The remote job feb72ca6-b602-497e-a354-8bd44ca31fdb has been completed.
# 2025-07-08 01:01:52,453 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:01:56,720 - INFO - The remote job 1de08238-ecc5-42ac-b90f-c6caf8ff86a9 has been completed.

# %%
x_arr = range(0, testing_trials)
y_arr = []

for i in range(0, testing_trials):

    state = run_circuit(optimal_parameters[0], optimal_parameters[1], parabolic_min)
    y_arr.append(state.samples[0][0])

print(y_arr)
# Out:
# 2025-07-08 01:01:57,029 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:01,153 - INFO - The remote job 3e711aaf-0265-403a-83d6-9e192cc67c82 has been completed.
# 2025-07-08 01:02:01,471 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:05,369 - INFO - The remote job 13dde5e8-fe54-4c03-bb85-4cca1285ce3f has been completed.
# 2025-07-08 01:02:05,664 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:10,021 - INFO - The remote job 12ee66f4-c431-4cd9-8c8a-2a49d3bff22f has been completed.
# 2025-07-08 01:02:10,369 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:14,521 - INFO - The remote job b37371ce-b2e0-4987-93e6-1e603e4f297c has been completed.
# 2025-07-08 01:02:14,811 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:19,133 - INFO - The remote job b09ed5e0-e51c-455a-8dc2-9c04c65f7c83 has been completed.
# 2025-07-08 01:02:19,418 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:22,677 - INFO - The remote job e5fbce8d-f241-414e-809b-cb289054c114 has been completed.
# 2025-07-08 01:02:22,995 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:25,876 - INFO - The remote job f88a99c8-b67f-444d-8b3c-6e052964d7be has been completed.
# 2025-07-08 01:02:26,258 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:30,497 - INFO - The remote job f966aa27-62e8-47ad-8c81-4a7f716b229c has been completed.
# 2025-07-08 01:02:30,798 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:33,977 - INFO - The remote job b16f4ae3-12ab-4a31-9122-2eb0a5fa72f0 has been completed.
# 2025-07-08 01:02:34,315 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:38,932 - INFO - The remote job 7ea94b92-7777-44d0-9c93-6ecd290ddb85 has been completed.
# 2025-07-08 01:02:39,258 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:43,662 - INFO - The remote job 0d002d0c-8b32-404d-a836-87086e1f0825 has been completed.
# 2025-07-08 01:02:44,007 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:46,998 - INFO - The remote job b7f1c307-b463-4f8f-bd42-fd9ae9aa33cc has been completed.
# 2025-07-08 01:02:47,298 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:02:51,860 - INFO - The remote job c829a43a-efa3-4612-ac71-5d2ad9bbbdb9 has been completed.
# 2025-07-08 01:02:52,155 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01
- INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:05:53,200 - INFO - The remote job 45975469-4588-45fc-9dc3-d57a189153df has been completed.
# 2025-07-08 01:05:53,507 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:05:58,130 - INFO - The remote job a3a62027-f5db-40b4-a50d-cb2f4336c07a has been completed.
# 2025-07-08 01:05:58,439 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:01,318 - INFO - The remote job ad066bf1-c45d-40f1-8f33-91c5dbd2405d has been completed.
# 2025-07-08 01:06:01,669 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:05,812 - INFO - The remote job b1ce5d3b-dad8-4003-a3d4-e901f916a318 has been completed.
# 2025-07-08 01:06:06,137 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:10,387 - INFO - The remote job 7e046351-2f2d-43dd-9fbf-c47699a5d263 has been completed.
# 2025-07-08 01:06:10,658 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:15,334 - INFO - The remote job 03024e01-4147-4222-b346-258e488d6736 has been completed.
# 2025-07-08 01:06:15,624 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:19,847 - INFO - The remote job 9f76d258-ee01-40cb-81fe-1d56a76d0c3d has been completed.
# 2025-07-08 01:06:20,153 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:24,392 - INFO - The remote job 156d65ab-c5bf-4280-a3b9-d2038dccbfeb has been completed.
# 2025-07-08 01:06:24,778 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:27,703 - INFO - The remote job b244c925-2481-492b-95ff-d9c9d06e4351 has been completed.
# 2025-07-08 01:06:28,024 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:32,353 - INFO - The remote job 7fe4d765-f539-419d-bb81-57417f8d1b55 has been completed.
# 2025-07-08 01:06:32,672 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:37,075 - INFO - The remote job ef4b77c6-4a26-402a-94f0-bab68e024bf2 has been completed.
# 2025-07-08 01:06:37,369 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:41,622 - INFO - The remote job d3ca929e-d461-4e14-82cd-3e43fff31142 has been completed.
# 2025-07-08 01:06:41,925 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:46,234 - INFO - The remote job 81dafc2e-b8b4-4885-829b-cab5a6bb9e7a has been completed.
# 2025-07-08 01:06:46,542 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:50,631 - INFO - The remote job 81cfead5-e422-4a3b-85cb-a5bd920316c0 has been completed.
# 2025-07-08 01:06:50,931 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:55,207 - INFO - The remote job ddf897fe-5026-43e8-aefd-acb4ec3968a6 has been completed.
# 2025-07-08 01:06:55,522 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:06:59,541 - INFO - The remote job 891d3978-fbe9-4d59-a1de-2e0dd0f2d17d has been completed.
# 2025-07-08 01:06:59,823 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:04,394 - INFO - The remote job c0acc883-8333-4bd4-8781-62a8827ae322 has been completed.
# 2025-07-08 01:07:04,664 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:07,713 - INFO - The remote job aa4bac5e-5fc0-4656-a69f-30e277652ea3 has been completed.
# 2025-07-08 01:07:08,018 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:10,831 - INFO - The remote job 97e28ba3-09eb-4339-be49-82d72120e207 has been completed.
# 2025-07-08 01:07:11,125 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:15,160 - INFO - The remote job 55582bb5-877f-46ca-9915-535c4c236496 has been completed.
# 2025-07-08 01:07:15,452 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:19,574 - INFO - The remote job b67dad8b-91d9-42f5-b150-c2a7d2a4547b has been completed.
# 2025-07-08 01:07:19,862 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:24,040 - INFO - The remote job f0ff6762-1a5d-410a-8983-6ef722033273 has been completed.
# 2025-07-08 01:07:24,360 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:27,750 - INFO - The remote job 55c51ffe-b88b-47f4-9a09-eacb10ea474e has been completed.
# 2025-07-08 01:07:28,038 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:30,807 - INFO - The remote job bfe9a3c4-694d-404a-b324-542611b8a1da has been completed.
# 2025-07-08 01:07:31,156 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:35,704 - INFO - The remote job 1c9f6d24-f725-4a0e-aefd-dda3612c2d6e has been completed.
# 2025-07-08 01:07:36,003 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:39,226 - INFO - The remote job a0e59f27-5adc-4080-8ac8-df6ee9b4282f has been completed.
# 2025-07-08 01:07:39,598 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:43,977 - INFO - The remote job 00d80b9f-daf7-43dc-a1fc-5f9d23680a1b has been completed.
# 2025-07-08 01:07:44,280 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:48,939 - INFO - The remote job de5e44ac-30ac-4060-bacd-142408b2cd71 has been completed.
# 2025-07-08 01:07:49,256 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:53,508 - INFO - The remote job d9c9cba0-c1e5-4614-a342-3713547e750f has been completed.
# 2025-07-08 01:07:53,857 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:56,629 - INFO - The remote job 1a5bd6cd-dc7b-4b8d-993e-5869a753155d has been completed.
# 2025-07-08 01:07:56,961 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:07:59,877 - INFO - The remote job a93c33a5-5592-4a64-882b-32919ebde47c has been completed.
# 2025-07-08 01:08:00,168 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:04,483 - INFO - The remote job 40604956-7b03-41ee-bdc9-4290bf428b54 has been completed.
# 2025-07-08 01:08:04,787 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:09,010 - INFO - The remote job e483fd45-b500-42a7-9044-c93d73bc51a1 has been completed.
# 2025-07-08 01:08:09,351 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:12,334 - INFO - The remote job 750828fa-7f79-40ae-8b75-adb742638271 has been completed.
# 2025-07-08 01:08:12,632 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:15,469 - INFO - The remote job d9f7915e-7051-4aca-9b6f-3a17cee1d532 has been completed.
# 2025-07-08 01:08:15,799 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:20,156 - INFO - The remote job 26de5f6c-19cc-40ee-971e-51e64b6c1334 has been completed.
# 2025-07-08 01:08:20,455 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:23,439 - INFO - The remote job b65bba9b-5472-476d-8ff0-8b4bf9982bd0 has been completed.
# 2025-07-08 01:08:23,760 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:26,432 - INFO - The remote job 35d2d9a5-d31a-4866-8887-bee1f37744fe has been completed.
# 2025-07-08 01:08:26,779 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:31,064 - INFO - The remote job e2a776e0-9d44-40ef-b130-39795c7aa7ed has been completed.
# 2025-07-08 01:08:31,389 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:35,674 - INFO - The remote job fd8bb225-7300-4c99-9822-a646a179fdd3 has been completed.
# 2025-07-08 01:08:36,005 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:40,177 - INFO - The remote job b4b0f217-c840-4ef9-984e-5d69a07cb877 has been completed.
# 2025-07-08 01:08:40,475 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:44,668 - INFO - The remote job d6685cb1-ced8-4302-8397-5e8746abdf2a has been completed.
# 2025-07-08 01:08:44,997 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:48,014 - INFO - The remote job 6dce675e-ebf2-4788-be40-7ceba5e02e50 has been completed.
# 2025-07-08 01:08:48,310 - INFO - Compiling program for device simulon_gaussian using compiler gaussian.
# 2025-07-08 01:08:52,684 - INFO - The remote job 88750e52-d041-400d-9d09-fa3b908f83af has been completed.
# [np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236), np.float64(2.86615359284236)]
